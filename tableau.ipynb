# %%
import pandas as pd
import numpy as np
import seaborn as sns
sns.set_style('darkgrid', {'legend.frameon':True})
sns.set(font_scale = 1.5)

import matplotlib.pyplot as plt
import re
import warnings

warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
df = pd.read_csv('all_teams.csv')
df.set_index('gameId', inplace = True)
df = df[df.situation == 'all']
df.season = df.season.astype('str')
df = df[df.season == '2019']
df.gameDate = pd.to_datetime(df.gameDate, format = '%Y%m%d')
df.to_csv('game_data_full.csv')

# %%
df.gameDate.value_counts()
# Out:
# 2019-11-16    30
# 2019-12-14    28
# 2019-10-12    28
# 2019-11-23    28
# 2019-11-02    28
#               ..
# 2020-01-22     4
# 2020-02-24     2
# 2019-11-28     2
# 2020-01-01     2
# 2019-12-30     2
# Name: gameDate, Length: 155, dtype: int64

# %%
df
# Out:
#            team season name playerTeam opposingTeam home_or_away   gameDate  \
# gameId
# 2019020006  NYR   2019  NYR        NYR          WPG         HOME 2019-10-03
# 2019020020  NYR   2019  NYR        NYR          OTT         AWAY 2019-10-05
# 2019020061  NYR   2019  NYR        NYR          EDM         HOME 2019-10-12
# 2019020100  NYR   2019  NYR        NYR          N.J         AWAY 2019-10-17
# 2019020109  NYR   2019  NYR        NYR          WSH         AWAY 2019-10-18
# ...         ...    ...  ...        ...          ...          ...        ...
# 2019021016  L.A   2019  L.A        L.A          VGK         AWAY 2020-03-01
# 2019021041  L.A   2019  L.A        L.A          TOR         HOME 2020-03-05
# 2019021052  L.A   2019  L.A        L.A          MIN         HOME 2020-03-07
# 2019021069  L.A   2019  L.A        L.A          COL         HOME 2020-03-09
# 2019021082  L.A   2019  L.A        L.A          OTT         HOME 2020-03-11
#
#               position situation  xGoalsPercentage  ...  \
# gameId                                              ...
# 2019020006  Team Level       all            0.4453  ...
# 2019020020  Team Level       all            0.5328  ...
# 2019020061  Team Level       all            0.3725  ...
# 2019020100  Team Level       all            0.4887  ...
# 2019020109  Team Level       all            0.3393  ...
# ...                ...       ...               ...  ...
# 2019021016  Team Level       all            0.3392  ...
# 2019021041  Team Level       all            0.4096  ...
# 2019021052  Team Level       all            0.5348  ...
# 2019021069  Team Level       all            0.6696  ...
# 2019021082  Team Level       all            0.7001  ...
#
#             unblockedShotAttemptsAgainst  \
# gameId
# 2019020006                          63.0
# 2019020020                          44.0
# 2019020061                          50.0
# 2019020100                          47.0
# 2019020109                          45.0
# ...                                  ...
# 2019021016                          65.0
# 2019021041                          58.0
# 2019021052                          42.0
# 2019021069                          35.0
# 2019021082                          42.0
#
#             scoreAdjustedUnblockedShotAttemptsAgainst  dZoneGiveawaysAgainst  \
# gameId
# 2019020006                                     63.802                    8.0
# 2019020020                                     40.745                    8.0
# 2019020061                                     51.252                    7.0
# 2019020100                                     47.232                    3.0
# 2019020109                                     46.304                    7.0
# ...                                               ...                    ...
# 2019021016                                     59.136                    2.0
# 2019021041                                     59.342                    4.0
# 2019021052                                     41.110                    4.0
# 2019021069                                     33.886                    6.0
# 2019021082                                     43.883                    3.0
#
#             xGoalsFromxReboundsOfShotsAgainst  \
# gameId
# 2019020006                              0.664
# 2019020020                              0.510
# 2019020061                              0.475
# 2019020100                              0.464
# 2019020109                              0.587
# ...                                       ...
# 2019021016                              0.690
# 2019021041                              0.545
# 2019021052                              0.528
# 2019021069                              0.348
# 2019021082                              0.381
#
#             xGoalsFromActualReboundsOfShotsAgainst  reboundxGoalsAgainst  \
# gameId
# 2019020006                                   0.759                 0.759
# 2019020020                                   0.871                 0.871
# 2019020061                                   0.478                 0.478
# 2019020100                                   0.000                 0.000
# 2019020109                                   1.957                 1.957
# ...                                            ...                   ...
# 2019021016                                   0.583                 0.583
# 2019021041                                   0.664                 0.664
# 2019021052                                   1.843                 1.843
# 2019021069                                   0.000                 0.037
# 2019021082                                   0.584                 0.584
#
#             totalShotCreditAgainst  scoreAdjustedTotalShotCreditAgainst  \
# gameId
# 2019020006                   3.520                                3.628
# 2019020020                   2.086                                1.965
# 2019020061                   3.636                                3.730
# 2019020100                   3.852                                3.829
# 2019020109                   4.353                                4.340
# ...                            ...                                  ...
# 2019021016                   4.691                                4.349
# 2019021041                   3.542                                3.667
# 2019021052                   2.055                                2.046
# 2019021069                   1.952                                1.953
# 2019021082                   2.046                                2.162
#
#             scoreFlurryAdjustedTotalShotCreditAgainst  playoffGame
# gameId
# 2019020006                                      3.600            0
# 2019020020                                      1.911            0
# 2019020061                                      3.707            0
# 2019020100                                      3.793            0
# 2019020109                                      4.118            0
# ...                                               ...          ...
# 2019021016                                      4.255            0
# 2019021041                                      3.565            0
# 2019021052                                      1.996            0
# 2019021069                                      1.902            0
# 2019021082                                      2.158            0
#
# [2164 rows x 110 columns]
