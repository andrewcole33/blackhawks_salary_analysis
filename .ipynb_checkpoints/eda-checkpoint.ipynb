# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as pyplot
import re
from helper import clean_team_salary_df
from helper import clean_full_df

import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline
# %load_ext autoreload

# %% [markdown]
# # Clean Blackhawks Salary DataFrame

# %%
salary_df = pd.read_csv('hawks_salary.csv')
salary_df = salary_df[1:]
salary_df = clean_team_salary_df(salary_df)

# %%
salary_df.to_csv('hawks_salary_clean.csv')

# %% [markdown]
# # Clean Blackhawks Player Stats DataFrame

# %%
hawks_df = pd.read_csv('skaters.csv')

# %%
hawks_df
# Out:
#       playerId  season             name team position situation  games_played  \
# 0      8475169    2019     Evander Kane  S.J        L     other            64
# 1      8475169    2019     Evander Kane  S.J        L       all            64
# 2      8475169    2019     Evander Kane  S.J        L      5on5            64
# 3      8475169    2019     Evander Kane  S.J        L      4on5            64
# 4      8475169    2019     Evander Kane  S.J        L      5on4            64
# ...        ...     ...              ...  ...      ...       ...           ...
# 4410   8477922    2019  Melker Karlsson  S.J        C     other            61
# 4411   8477922    2019  Melker Karlsson  S.J        C       all            61
# 4412   8477922    2019  Melker Karlsson  S.J        C      5on5            61
# 4413   8477922    2019  Melker Karlsson  S.J        C      4on5            61
# 4414   8477922    2019  Melker Karlsson  S.J        C      5on4            61
#
# ...

# %%
df = clean_full_df(hawks_df, salary_df, 'all')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-708e3e16a6fa> in <module>
# ----> 1 df = clean_full_df(hawks_df, salary_df, 'all')
#
# NameError: name 'clean_full_df' is not defined
